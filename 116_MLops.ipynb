# %% [markdown]
# # developing web APIs

# %% [markdown]
# ![Screenshot 2026-06-13 122027.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-13 123919.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-13 124028.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-13 132214.png](data:image/png;base64,...)
